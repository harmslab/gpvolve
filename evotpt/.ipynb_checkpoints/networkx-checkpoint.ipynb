# %%
from gpmap import GenotypePhenotypeMap
from gpmap.utils import *
from gpgraph import GenotypePhenotypeGraph, draw_flattened
import networkx as nx

# %%
# Turn dataset into gpmap object
dataset = "/Users/leandergoldbach/Utrecht/Minor/evobiophys/genotype-phenotype-maps/weinreich.json"
gpm = GenotypePhenotypeMap.read_json(dataset)

# %%
# Turn the genotype-phenotype map into a networkx object
G = GenotypePhenotypeGraph(gpm)
# Draw the graph
draw_flattened(G, with_labels=False, node_size=100)

# %%
G.add_model(strong_selection_weak_mutation)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-c0b2f56079b2> in <module>()
# ----> 1 G.add_model(strong_selection_weak_mutation)
#
# AttributeError: 'GenotypePhenotypeGraph' object has no attribute 'add_model'
